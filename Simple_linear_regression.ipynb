# %% [markdown]
# <a href="https://colab.research.google.com/github/ARJUN108-verma/Machine_Learning/blob/main/Simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Salary_Data.csv')

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %% [markdown]
# #simple linear regression

# %%
x = df[['Years of Experience']]
y = df['Salary']

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train.head()
# Out:
#       Years of Experience
# 4092                 16.0
# 2180                  6.0
# 5224                  1.0
# 459                   5.0
# 6118                 16.0

# %%
x_test.head()
# Out:
#       Years of Experience
# 1883                  9.0
# 2630                  4.0
# 498                   1.0
# 5973                  3.0
# 4108                  5.0

# %%
y_train.head()
# Out:
# 4092    160000.0
# 2180    115000.0
# 5224     55000.0
# 459     145000.0
# 6118    215000.0
# Name: Salary, dtype: float64

# %%
y_test.head()
# Out:
# 1883    150000.0
# 2630     75969.0
# 498     100000.0
# 5973     60000.0
# 4108     80000.0
# Name: Salary, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([121786.35063152,  86314.68168168,  65031.68031178, ...,
#        135975.01821145,  72126.01410174,  72126.01410174])

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, pred)
r2
# Out:
# 0.6461457727931804

# %%
m = lr.coef_
m
# Out:
# array([7094.33378997])

# %%
c = lr.intercept_
c
# Out:
# np.float64(57937.3465218094)

# %%
m * 9.0 + c
# Out:
# array([121786.35063152])

# %%
m * 4.0 + c
# Out:
# array([86314.68168168])

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.scatterplot(x = 'Years of Experience', y = 'Salary', data = df)
plt.plot(x_test, pred, color = 'red')
plt.show()
