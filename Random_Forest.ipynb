# %% [markdown]
# <a href="https://colab.research.google.com/github/ARJUN108-verma/Machine_Learning/blob/main/Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Random_Forest:-

# %% [markdown]
# A Random Forest is a machine learning algorithm that uses an ensemble of decision trees to make predictions. It combines the outputs of multiple decision trees to achieve a more accurate and robust result, handling both classification and regression tasks

# %% [markdown]
# Key Concepts:
# Ensemble Learning:
# Random forests are an example of ensemble learning, where multiple models (in this case, decision trees) are combined to improve performance.
# Decision Trees:
# A decision tree is a flowchart-like structure where each internal node represents a "test" on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label or a numerical value.
# Bagging:
# Random forests utilize a technique called bagging (bootstrap aggregating) where multiple decision trees are trained on different random subsets of the training data, with replacement.
# Random Feature Selection:
# At each node of a decision tree, only a random subset of features is considered for splitting, further enhancing the diversity of the trees.

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/loan_approval_dataset.csv')

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
df.drop(columns= ['loan_id'],inplace=True)

# %%
df.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
df['loan_status'] = lb.fit_transform(df['loan_status'])

# %%
df.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
# ...

# %%
x = df.drop('loan_status',axis=1)
y = df['loan_status']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4264    1
# 4265    0
# 4266    1
# 4267    0
# 4268    0
# Name: loan_status, Length: 4269, dtype: int64

# %%
cat_call = x.select_dtypes(include='object').columns.to_list()

# %%
num_call = x.select_dtypes(include = ['int64', 'float64']).columns.to_list()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler

# %%
preprocessing = ColumnTransformer([
    ('Scaling', StandardScaler(), num_call),
    ('Encoding', OneHotEncoder(drop='first'), cat_call)
], remainder='passthrough')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
clf = Pipeline([
    ('preprocessing', preprocessing),
    ('model', RandomForestClassifier(random_state=42))
])

# %%
clf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Scaling', StandardScaler(),
#                                                   ['no_of_dependents',
#                                                    'income_annum',
#                                                    'loan_amount', 'loan_term',
#                                                    'cibil_score',
#                                                    'residential_assets_value',
#                                                    'commercial_assets_value',
#                                                    'luxury_assets_value',
#                                                    'bank_asset_value']),
#                                                  ('Encoding',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['education',
# ...

# %%
clf.score(x_test,y_test)
# Out:
# 0.9754098360655737

# %%
from sklearn.metrics import classification_report
y_pred = clf.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       536
#            1       0.98      0.96      0.97       318
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.97      0.97       854
# weighted avg       0.98      0.98      0.98       854

# %%
import matplotlib as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
